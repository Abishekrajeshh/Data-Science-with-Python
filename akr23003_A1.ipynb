# %% [markdown]
# # EDA as a group (Spring 2024)
# ----------------------------------------
# * Dave Wanik - OPIM 5512: Data Science Using Python - University of Connecticut

# %% [markdown]
# **Your Name Here:** Abishek Karnan Rajesh
#
# Groups of four students - give feedback to at least one other person (everyone must receive feedback). First come, first serve!

# %% [markdown]
# The purpose of this assignment is to get you working with the two most common visualization libraries in Python, `matplotlib` (plt) and `seaborn` (sns).
#
# # Rubric
# * Each student will decide to use `matplotlib` or `seabron` or both.
# * (10 pts) Find **FIVE** interesting examples blogs/websites where datasets are cleaned and/or  EDA is completed with `matplotlib` or `sns`. List and describe the sources that you used in a subheader with a short description of the website.
# * (60 pts) Each student will use the dataset that is given to create a total of **TWO** interesting plots (using `matplotlib` or `sns` or a mix). and **ONE** interesting table for each data set ("Incentives by State" and "Efficiency by vehicle".) Each item must have a useful caption with a description of what the output shows and what insights can be derived.
# * (20 pts) Students will post to HuskyCT forum for peer review - thoughtful comments MUST be given (what was good, what could be improved, something new that could be added.) Since this is a dirty dataset, I expect some comments to be about data cleaning!
# * After posting their script for review for peer feedback (as both as shareable link viewable to anyone with the link and as an uploaded file to HuskyCT), students will compare each others code quality and captions (business value of plots and tables) and make a suggestions for improvement.
#
# ## Examples of common feedback items on HuskyCT
# * "I like how you tried four different plots instead of just using one plot over and over again"
# * "That way of cleaning that column was amazing - I'm going to try that on my script too - my way was too manual, yours was way cleaner"
# * "Your caption for Figure 2 could be more clear - maybe say something like this..."
# * "I think it would be interesting to redo Table 2 but group by variable X instead of Z, that way you could get a better understanding of..."
# * "I think you could have made a more thougtful caption for Figure 1 - what is the real value of the plot?"

# %% [markdown]
# ❌ Do not just blindly copy/paste AI-generated code - if I ask you to explain something you submit for credit and you can't do it, you get a 0 for the entire assignment. Make sure you understand what you are doing and come to office hours if you are stuck!

# %% [markdown]
# # Sources
# Here is an example of a good source:
# * [How to Perform Exploratory Data Analysis with Seaborn - Lorraine Lee](https://towardsdatascience.com/how-to-perform-exploratory-data-analysis-with-seaborn-97e3413e841d)
#   * This article was useful because it had a thorough presentation on making plots for categorical and numeric data in seaborn and had lots of 'hackable' code for making subplots.
#
#   You should have five cool sources!

# %% [markdown]
# # Overview

# %% [markdown]
# EVs aren't going away, why not apply what you've learned about EDA to a cool new (dirty) dataset? There are two datasets from Wikipedia for you to check. You will make 3 cool outputs for each dataset, share it with your group (and get feedback!), then you will submit to me.

# %% [markdown]
# ![pacifica](https://di-uploads-pod8.dealerinspire.com/ranchochryslerjeepdodgeram/uploads/2023/03/2023-Chrysler-Pacifica-SilverMist-Cityscape.jpeg)

# %% [markdown]
# Resources I referred which is FIVE interesting examples blogs/websites
#
#
# https://miykael.github.io/blog/2022/advanced_eda/
# https://www.reddit.com/r/datasets/comments/v8em02/interesting_datasets_for_exploratory_data_analysis/
#
# https://towardsdatascience.com/exploratory-data-analysis-eda-python-87178e35b14
#
# https://sercangl.medium.com/exploratory-data-analysis-with-python-code-examples-3445fdeef702
# https://github.com/mwaskom/seaborn/tree/master/examples

# %% [markdown]
# ## Read the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# mute setting with copying warning
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# # 🔵 Incentives by State

# %% [markdown]
# Take a look at this table - the primary key actually spans two or three columns - State and Type of PEV/Vehicle. And you already see that it's messy - look at Colarado vs. Connecticut! You will need to recode values using replace values.

# %%
df_state = pd.read_html('https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_the_United_States')[1]
df_state
# Out:
#                    State Amount of incentive             Type of PEV/vehicle  \
# 0                Arizona                 NaN                            BEVs
# 1             California        up to $2,500                            BEVs
# 2             California        up to $2,500                           PHEVs
# 3             California        up to $1,500  Electric motorcycles  and NEVs
# 4               Colorado              $5,000                  BEVs and PHEVs
# 5            Connecticut        up to $3,000                      BEVs, PHEV
# 6               Delaware        up to $2,200                              EV
# 7   District of Columbia                 NaN                  BEVs and PHEVs
# 8                Florida                 NaN                  BEVs and PHEVs
# 9                Georgia                  $0                            ZEVs
# 10               Georgia        up to $2,500     Alternative fuel conversion
# ...

# %%
df_state.head(10)
# Out:
#                   State Amount of incentive             Type of PEV/vehicle  \
# 0               Arizona                 NaN                            BEVs
# 1            California        up to $2,500                            BEVs
# 2            California        up to $2,500                           PHEVs
# 3            California        up to $1,500  Electric motorcycles  and NEVs
# 4              Colorado              $5,000                  BEVs and PHEVs
# 5           Connecticut        up to $3,000                      BEVs, PHEV
# 6              Delaware        up to $2,200                              EV
# 7  District of Columbia                 NaN                  BEVs and PHEVs
# 8               Florida                 NaN                  BEVs and PHEVs
# 9               Georgia                  $0                            ZEVs
#
#                                    Type of incentive Carpool lane access  \
# ...

# %%
df_state['Carpool lane access'].replace('Yes[60]', 'Yes', inplace=True) # changing the error in the column

# Dropping rows where 'Carpool lane access' has null values
df_state = df_state.dropna(subset=['Carpool lane access'])

df_state = df_state.drop(columns=['Comments'])# Dropped the comments column


df_state
# Out:
#                    State Amount of incentive             Type of PEV/vehicle  \
# 0                Arizona                 NaN                            BEVs
# 1             California        up to $2,500                            BEVs
# 2             California        up to $2,500                            PHEV
# 3             California        up to $1,500  Electric motorcycles  and NEVs
# 4               Colorado              $5,000                  BEVs and PHEVs
# 5            Connecticut        up to $3,000                  BEVs and PHEVs
# 6               Delaware        up to $2,200                              EV
# 7   District of Columbia                 NaN                  BEVs and PHEVs
# 8                Florida                 NaN                  BEVs and PHEVs
# 9                Georgia                  $0                            ZEVs
# 10               Georgia        up to $2,500     Alternative fuel conversion
# ...

# %%
#categorical_distribution
from matplotlib import pyplot as plt
import seaborn as sns
df_state.groupby('Carpool lane access').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 0 to 42
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                41 non-null     object
#  1   Amount of incentive  20 non-null     object
#  2   Type of PEV/vehicle  39 non-null     object
#  3   Type of incentive    30 non-null     object
#  4   Carpool lane access  41 non-null     object
# dtypes: object(5)
# memory usage: 1.9+ KB

# %%
df_state.shape
# Out:
# (41, 5)

# %% [markdown]
# I'll help you get started. Looks like we need to combine 'BEVs and PHEVs' and 'BEVs, PHEV'. We can just replace values to make this happen! Then we are ready to go!

# %%
# missing values in entire dataframe
df_state.isnull().sum().sum()
# Out:
# 34

# %%
# df.info() is the one stop shop for inspecting a data frame
df_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 0 to 42
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State                41 non-null     object
#  1   Amount of incentive  20 non-null     object
#  2   Type of PEV/vehicle  39 non-null     object
#  3   Type of incentive    30 non-null     object
#  4   Carpool lane access  41 non-null     object
# dtypes: object(5)
# memory usage: 1.9+ KB

# %%
# describe() gives summary statistics
df_state.describe()
# Out:
#              State Amount of incentive Type of PEV/vehicle  Type of incentive  \
# count           41                  20                  39                 30
# unique          36                  13                  11                 11
# top     California        up to $1,500      BEVs and PHEVs  Income tax credit
# freq             3                   4                  20                 11
#
#        Carpool lane access
# count                   41
# unique                   2
# top                     No
# freq                    23

# %%
# return unique values in column
df_state['Type of PEV/vehicle'].value_counts()
# Out:
# BEVs and PHEVs                    20
# BEVs                               5
# PHEV                               3
# EV                                 2
# Alternative fuel conversion        2
# BEVs, PHEVs and conversions        2
# Electric motorcycles  and NEVs     1
# ZEVs                               1
# Commercial AFVs                    1
# BEVs, PHEVs and HEVs               1
# Conversions only                   1
# Name: Type of PEV/vehicle, dtype: int64

# %%
# replace value in column
df_state['Type of PEV/vehicle'].replace(['BEVs and PHEVs', 'BEVs, PHEV'], 'BEVs and PHEVs', inplace=True)
# check your work - it worked!
df_state['Type of PEV/vehicle'].value_counts()
# Out:
# BEVs and PHEVs                    20
# BEVs                               5
# PHEV                               3
# EV                                 2
# Alternative fuel conversion        2
# BEVs, PHEVs and conversions        2
# Electric motorcycles  and NEVs     1
# ZEVs                               1
# Commercial AFVs                    1
# BEVs, PHEVs and HEVs               1
# Conversions only                   1
# Name: Type of PEV/vehicle, dtype: int64

# %%
df_state['Type of PEV/vehicle'].replace(['PHEV','PHEVs'], 'PHEV', inplace=True)
#check if it worked
df_state['Type of PEV/vehicle'].value_counts()
# Out:
# BEVs and PHEVs                    20
# BEVs                               5
# PHEV                               3
# EV                                 2
# Alternative fuel conversion        2
# BEVs, PHEVs and conversions        2
# Electric motorcycles  and NEVs     1
# ZEVs                               1
# Commercial AFVs                    1
# BEVs, PHEVs and HEVs               1
# Conversions only                   1
# Name: Type of PEV/vehicle, dtype: int64

# %% [markdown]
# [link text](https://)Use this as inspiration to make three interesting outputs - at least one plot and at least one table.

# %% [markdown]
# ## 🔴 Interesting Output 1

# %% [markdown]
# This pie chart displays the proportion of different types of plug-in electric vehicles (PEVs) and vehicles mentioned in the dataset.

# %%
pev_type_counts = df_state['Type of PEV/vehicle'].value_counts()
labels = pev_type_counts.index
sizes = pev_type_counts.values

plt.figure(figsize=(10, 10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Types of PEVs')
plt.legend(labels, loc='upper right', bbox_to_anchor=(1.2, 1.2))

plt.show()

# %% [markdown]
# Predominant Type: Identify the most prevalent type of PEV by looking at the slice with the largest percentage. This information helps understand the primary category that dominates the dataset in terms of PEV types.
#
# Top Three Types: Determine the top three types of PEVs with the highest percentages. This insight gives a more nuanced understanding of the major categories, beyond just the predominant type, and helps highlight the diversity within the dataset.
#
# Rare or Uncommon Types: Identify any PEV types that have very small slices in the pie chart. These represent less common or niche categories. Understanding these less prevalent types can be crucial for comprehensive insights into the dataset.
#
# Overall Diversity: Assess the overall diversity of PEV types. If the pie chart shows a wide distribution with several moderately sized slices, it indicates a diverse set of PEVs in the dataset. On the other hand, if one or two types dominate significantly, the dataset may be less diverse in terms of PEV types.

# %% [markdown]
# ## 🔴 Interesting Output 2

# %% [markdown]
# This corrlation chart displays the cost to drive 25 miles Annaual fuel cost mentioned in the dataset.

# %%
# Table: Incentives by State
incentives_by_state = df_state.groupby('State')['Amount of incentive'].count().reset_index()
incentives_by_state = incentives_by_state.rename(columns={'Amount of incentive': 'Number of Incentives'})
incentives_by_state = incentives_by_state.sort_values(by='Number of Incentives', ascending=False)

# %%
incentives_by_state
# Out:
#                    State  Number of Incentives
# 1             California                     3
# 7                Georgia                     3
# 32                  Utah                     2
# 18               Montana                     1
# 12             Louisiana                     1
# 21            New Jersey                     1
# 25              Oklahoma                     1
# 17              Missouri                     1
# 27          Pennsylvania                     1
# 29        South Carolina                     1
# 13              Maryland                     1
# 11               Indiana                     1
# 4               Delaware                     1
# 3            Connecticut                     1
# 2               Colorado                     1
# 23        North Carolina                     0
# 30             Tennessee                     0
# 31                 Texas                     0
# 28          Rhode Island                     0
# ...

# %%
#Distribution chart

from matplotlib import pyplot as plt
incentives_by_state['Number of Incentives'].plot(kind='hist', bins=20, title='Number of Incentives')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Histogram:
#
# The code uses the .plot(kind='hist') method to create a histogram for the 'Number of Incentives' column in _df_1.
# A histogram is a graphical representation of the distribution of a dataset. It divides the data into bins and shows the frequency of observations in each bin.
#
#
# Bins:
#
# The histogram is divided into 20 bins (bins=20). This means the range of 'Number of Incentives' values is divided into 20 intervals, and the height of each bar represents the frequency of values within that interval.
#
#
# Title:
#
# The title of the histogram is set to 'Number of Incentives' using title='Number of Incentives'.
#
# Visualization:
#
# After executing the code, the plot is displayed using plt.show().

# %% [markdown]
# ## 🔴 Interesting Output 3

# %% [markdown]
# This chart displays the Distribution of Incentives for different Types of PEVs mentioned in the dataset.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(6, 6))
sns.countplot(data=df_state, y='Type of PEV/vehicle', order=df_state['Type of PEV/vehicle'].value_counts().index, palette='viridis', hue='Type of PEV/vehicle', dodge=False, legend=False)
plt.title('Distribution of Incentives for Different Types of PEVs')
plt.xlabel('Number of Incentives')
plt.ylabel('Type of PEV/vehicle')
# Add legend
plt.legend(title='Type of PEV/vehicle', loc='upper right')

# Set labels for x and y axes
plt.xlabel('Number of Incentives')
plt.ylabel('Type of PEV/vehicle')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# The count plot provides a visual representation of the distribution of incentives for different types of PEVs.
#
#
#
#
# It helps compare the number of incentives offered for each type of PEV.
# Overlapping bars without dodging make it easier to see the total number of incentives across types.
#
#
#
#
# Observing the plot can give insights into the popularity or emphasis on incentives for specific types of PEVs in the dataset.

# %% [markdown]
# # 🔵 Efficiency by vehicle

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_the_United_States')[4]
df
# Out:
#                                               Vehicle  \
#                                               Vehicle
# 0                    Hyundai Ioniq Electric[104][107]
# 1                             Toyota Prius Prime[109]
# 2                             Toyota Prius Prime[109]
# 3                           BMW i3 (60 A·h)[106][111]
# 4                                    Scion iQ EV[113]
# ..                                                ...
# 80                    Porsche Cayenne S E-Hybrid[168]
# 81                    Porsche Cayenne S E-Hybrid[168]
# 82                               McLaren P1[106][169]
# 83                               McLaren P1[106][169]
# 84  Notes: (1) In November 2010, EPA introduced MP...
#
#                                            Model year  \
#                                            Model year
# 0                                                2017
# 1                                                2017
# ...

# %% [markdown]
# I'll help you get started - real-world data is messy. See the header? See the last row? These will cause problems for you. The multi-index is ANNOYING for selecting the column you want, and the last row is a text cell that repeats for each column. This is a little advanced for new coders, but you have to have good instincts.
#
# * https://towardsdatascience.com/how-to-flatten-multiindex-columns-and-rows-in-pandas-f5406c50e569
# * https://stackoverflow.com/questions/26921651/how-to-delete-the-last-row-of-data-of-a-pandas-dataframe

# %%
# drop the last row
df = df[:-1]

# collapse the multi-index
df.columns = df.columns.get_level_values(0)

# check your work
df.head()
# Out:
#                             Vehicle        Model year   Operating mode (AER)  \
# 0  Hyundai Ioniq Electric[104][107]              2017  All-electric (124 mi)
# 1           Toyota Prius Prime[109]              2017    Electricity (25 mi)
# 2           Toyota Prius Prime[109]              2017          Gasoline only
# 3         BMW i3 (60 A·h)[106][111]  2014, 2015, 2016   All-electric (81 mi)
# 4                  Scion iQ EV[113]              2013   All-electric (38 mi)
#
#        EPA fuel economy ratings    EPA fuel economy ratings  \
# 0    136 mpg-e (25 kW·h/100 mi)  150 mpg-e (22 kW·h/100 mi)
# 1  133 mpg‑e (25.3 kW⋅h/100 mi)                           -
# 2                        54 mpg              55 mpg/ 53 mpg
# 3    124 mpg-e (27 kW·h/100 mi)  137 mpg-e (25 kW·h/100 mi)
# 4    121 mpg-e (28 kW·h/100 mi)  138 mpg-e (24 kW·h/100 mi)
#
#      EPA fuel economy ratings Cost to drive 25 miles  \
# 0  122 mpg-e (28 kW·h/100 mi)                  $0.81
# ...

# %% [markdown]
# See how the data is dirty? You need to clean it up! Get rid of special characters like dollar signs, periods, commas and anything else that is annoying! I leave this to you to figure out.

# %%
df.columns
# Out:
# Index(['Vehicle', 'Model year', 'Operating mode (AER)',
#        'EPA fuel economy ratings', 'EPA fuel economy ratings',
#        'EPA fuel economy ratings', 'Cost to drive 25 miles',
#        'Annual fuel cost(2) (15,000 mi)', 'Notes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Vehicle                          84 non-null     object
#  1   Model year                       84 non-null     object
#  2   Operating mode (AER)             84 non-null     object
#  3   EPA fuel economy ratings         84 non-null     object
#  4   EPA fuel economy ratings         84 non-null     object
#  5   EPA fuel economy ratings         84 non-null     object
#  6   Cost to drive 25 miles           84 non-null     object
#  7   Annual fuel cost(2) (15,000 mi)  84 non-null     object
#  8   Notes                            59 non-null     object
# dtypes: object(9)
# memory usage: 6.0+ KB

# %% [markdown]
# This one was hard for me too - there was a special character HIDING in this column name!

# %%
# look at how nasty this column name secretly is!
df.columns[7]
# Out:
# 'Annual fuel cost(2) (15,000\xa0mi)'

# %%
# rename the column
df.rename({df.columns[7]  :'Annual fuel cost'}, axis='columns', inplace=True)
# check your work
df.head()
# Out:
#                             Vehicle        Model year   Operating mode (AER)  \
# 0  Hyundai Ioniq Electric[104][107]              2017  All-electric (124 mi)
# 1           Toyota Prius Prime[109]              2017    Electricity (25 mi)
# 2           Toyota Prius Prime[109]              2017          Gasoline only
# 3         BMW i3 (60 A·h)[106][111]  2014, 2015, 2016   All-electric (81 mi)
# 4                  Scion iQ EV[113]              2013   All-electric (38 mi)
#
#        EPA fuel economy ratings    EPA fuel economy ratings  \
# 0    136 mpg-e (25 kW·h/100 mi)  150 mpg-e (22 kW·h/100 mi)
# 1  133 mpg‑e (25.3 kW⋅h/100 mi)                           -
# 2                        54 mpg              55 mpg/ 53 mpg
# 3    124 mpg-e (27 kW·h/100 mi)  137 mpg-e (25 kW·h/100 mi)
# 4    121 mpg-e (28 kW·h/100 mi)  138 mpg-e (24 kW·h/100 mi)
#
#      EPA fuel economy ratings Cost to drive 25 miles Annual fuel cost  \
# ...

# %%
# remove special characters
df['Annual fuel cost'] = df['Annual fuel cost'].str.replace('$', '')
df['Annual fuel cost'] = df['Annual fuel cost'].str.replace('-', '')
df['Annual fuel cost'] = df['Annual fuel cost'].str.replace(',', '')

df['Cost to drive 25 miles'] = df['Cost to drive 25 miles'].str.replace('$', '')
df['Cost to drive 25 miles'] = df['Cost to drive 25 miles'].str.replace('-', '')
df['Cost to drive 25 miles'] = df['Cost to drive 25 miles'].str.replace(',', '')

df.head()
# Out:
# <ipython-input-40-6a3c72c2cecc>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Annual fuel cost'] = df['Annual fuel cost'].str.replace('$', '')
# <ipython-input-40-6a3c72c2cecc>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Cost to drive 25 miles'] = df['Cost to drive 25 miles'].str.replace('$', '')
#                             Vehicle        Model year   Operating mode (AER)  \
# 0  Hyundai Ioniq Electric[104][107]              2017  All-electric (124 mi)
# 1           Toyota Prius Prime[109]              2017    Electricity (25 mi)
# 2           Toyota Prius Prime[109]              2017          Gasoline only
# ...

# %% [markdown]
# **Data Cleaning Part**

# %%
df['Vehicle'] = df['Vehicle'].str.split('[').str[0] # First column is cleaned
df['Operating mode (AER)'] = df['Operating mode (AER)'].str.split('(').str[0].str.strip() #Third column is cleaned
df.columns.values[3] = 'Combined-FuelEconomy' # Renaming the third column
df['Combined-FuelEconomy'] = df['Combined-FuelEconomy'].str.split('m').str[0].str.strip() # to have only numeric vales, I have removed all the charceters after M in the'mpg'
df.columns.values[4] = 'City-FuelEconomy'#Renaming the fourth column
df['City-FuelEconomy'] = df['City-FuelEconomy'].str.split('m').str[0].str.strip()
df.columns.values[5] = 'Highway-FuelEconomy'#Renaming the fifth column
df['Highway-FuelEconomy'] = df['Highway-FuelEconomy'].str.split('m').str[0].str.strip()
df
# Out:
#                         Vehicle  Model year      Operating mode (AER)  \
# 0        Hyundai Ioniq Electric      2017.0              All-electric
# 1            Toyota Prius Prime      2017.0               Electricity
# 2            Toyota Prius Prime      2017.0             Gasoline only
# 3               BMW i3 (60 A·h)         NaN              All-electric
# 4                   Scion iQ EV      2013.0              All-electric
# ..                          ...         ...                       ...
# 79  Porsche Panamera S E-Hybrid      2014.0             Gasoline only
# 80   Porsche Cayenne S E-Hybrid      2015.0  Electricity and gasoline
# 81   Porsche Cayenne S E-Hybrid      2015.0             Gasoline only
# 82                   McLaren P1      2014.0  Electricity and gasoline
# 83                   McLaren P1      2014.0             Gasoline only
#
#    Combined-FuelEconomy City-FuelEconomy Highway-FuelEconomy  \
# 0                   136              150                 122
# ...

# %% [markdown]
# With special characters, the column is hiding as a string - so you can't do math on it! You need to convert in to numeric. And once it's numeric, you can make cool plots and compute summary stats.

# %%
# convert column to numeric
df['Cost to drive 25 miles'] = pd.to_numeric(df['Cost to drive 25 miles'])

# %%
# convert column to numeric
df['Model year'] = pd.to_numeric(df['Model year'], errors='coerce')

# %%
# convert column to numeric
df['Annual fuel cost'] = pd.to_numeric(df['Annual fuel cost'])
df['Annual fuel cost'].hist()
# Out:
# <Axes: >

# %% [markdown]
# I have given you most of the tools you need to be successul! Take your time and try to crack this dataset open. Use AI to help you make even more amazing outputs if you want, but you have to understand what you coded, don't just copy blindly.

# %% [markdown]
# ## 🔴 Interesting Output 4

# %%
#Heatmap - Correlation matrix for numerical columns
correlation_matrix = df[['Cost to drive 25 miles', 'Annual fuel cost']].corr()
plt.figure(figsize=(8, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The heatmap visually represents the correlation between the selected numeric columns. Positive values indicate a positive correlation, while negative values indicate a negative correlation.
#
#
#
# A value close to 1 or -1 suggests a strong correlation, while values close to 0 suggest a weak correlation.
#
#
# Understanding the correlation matrix helps identify relationships between variables, which can be valuable in data analysis and decision-making.
#
#
#
#
# Features with high positive or negative correlations might influence each other, and this information can guide further exploration or modeling decisions.

# %% [markdown]
# ## 🔴 Interesting Output 5

# %% [markdown]
# In this histogram displays the distribution of annual fuel costs for the vehicles in the dataset

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.histplot(df['Annual fuel cost'].dropna(), bins=20, kde=False, color='skyblue', edgecolor='black')
plt.title('Distribution of Annual Fuel Costs', fontsize=16)
plt.xlabel('Annual Fuel Cost ($)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# The histogram provides a visual representation of the distribution of annual fuel costs.
#
# The x-axis represents the annual fuel cost in dollars, and the y-axis represents the frequency (or count) of each cost range.
#
#
# The distribution shape can reveal information about the central tendency, spread, and potential outliers in the annual fuel cost data.
#
#
# Insights into common cost ranges, the presence of peaks or gaps, and the overall spread of the data can be gained from the visualization.

# %%
# Now, we create a trend graph (line plot) for the average combined fuel economy over the model years
plt.figure(figsize=(15, 10))
sns.lineplot(data=df, x='Model year', y='Combined-FuelEconomy', marker='o')
plt.title('Trend of Average Combined Fuel Economy Over Model Years')
plt.xlabel('Model Year')
plt.ylabel('Average Combined Fuel Economy (mpg or mpg-e)')
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# The trend graph likely demonstrates advancements in vehicle technology, as indicated by an upward trajectory in average combined fuel economy over model years. Peaks may represent breakthroughs in efficiency or the introduction of regulations favoring fuel-efficient vehicles.

# %% [markdown]
# ## 🔴 Interesting Output 6

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Annual fuel cost'])
plt.title('Distribution of Annual Fuel Cost')
plt.xlabel('Annual Fuel Cost')
plt.show()

# %% [markdown]
# Central Tendency: The boxplot provides information about the central tendency
# of the 'Annual fuel cost' distribution, including the median (line inside the box) and the interquartile range (box).
#
#
#
# Outliers: Any data points beyond the "whiskers" of the box are considered outliers, providing insights into extreme values in the distribution.
# Distribution Spread: The length of the box and whiskers indicates the spread or dispersion of the data.
#
#
# Skewness: The asymmetry of the boxplot can give an indication of the skewness of the distribution. A longer whisker on one side suggests skewness in that direction.
